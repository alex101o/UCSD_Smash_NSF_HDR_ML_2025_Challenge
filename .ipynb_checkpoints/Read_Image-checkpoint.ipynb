# %%
from pathlib import Path
import pandas as pd
from PIL import Image
import io
import matplotlib.pyplot as plt
import os

# %%
directory_path = Path('hackdata/sentinel-beetles/data') # '.' refers to the current directory
files = [p for p in directory_path.iterdir() if p.is_file()]
train_files = list()
validation_files = list()

for file in files:
    if "train" in file.name:
        train_files.append(file.name)
    else:
        validation_files.append(file.name)
print(len(train_files))
print(len(validation_files))
out_dir = "training_images"
os.makedirs(out_dir, exist_ok=True)
# Out:
# 29
# 4

# %%
for i in range(0, 10):
    print(train_files[i])
    df = pd.read_parquet(os.path.join(directory_path, train_files[i]))

    for j in range(len(df)):
    # for j in range(1):
        img_bytes = df.loc[j, "file_path"]["bytes"]
        rel = str(df.loc[j, "relative_img_loc"])
        rel = rel.lstrip("/")
        out_path = os.path.join(out_dir, rel)
        if os.path.splitext(out_path)[1] == "":
            out_path += ".png"
        with open(out_path, "wb") as f:
            f.write(img_bytes)
    
print("yes")
# Out:
# train-00020-of-00029.parquet
# train-00025-of-00029.parquet
# train-00010-of-00029.parquet
# train-00006-of-00029.parquet
# train-00016-of-00029.parquet
# train-00024-of-00029.parquet
# train-00013-of-00029.parquet
# train-00015-of-00029.parquet
# train-00009-of-00029.parquet
# train-00012-of-00029.parquet
# yes

# %%
for i in range(10, 20):
    print(train_files[i])
    df = pd.read_parquet(os.path.join(directory_path, train_files[i]))

    for j in range(len(df)):
    # for j in range(1):
        img_bytes = df.loc[j, "file_path"]["bytes"]
        rel = str(df.loc[j, "relative_img_loc"])
        rel = rel.lstrip("/")
        out_path = os.path.join(out_dir, rel)
        if os.path.splitext(out_path)[1] == "":
            out_path += ".png"
        with open(out_path, "wb") as f:
            f.write(img_bytes)
    
print("yes")
# Out:
# train-00002-of-00029.parquet
# train-00023-of-00029.parquet
# train-00003-of-00029.parquet
# train-00022-of-00029.parquet
# train-00011-of-00029.parquet
# train-00000-of-00029.parquet
# train-00008-of-00029.parquet
# train-00021-of-00029.parquet
# train-00004-of-00029.parquet
# train-00001-of-00029.parquet

# %%
for i in range(20, len(train_files)):
    print(train_files[i])
    df = pd.read_parquet(os.path.join(directory_path, train_files[i]))

    for j in range(len(df)):
    # for j in range(1):
        img_bytes = df.loc[j, "file_path"]["bytes"]
        rel = str(df.loc[j, "relative_img_loc"])
        rel = rel.lstrip("/")
        out_path = os.path.join(out_dir, rel)
        if os.path.splitext(out_path)[1] == "":
            out_path += ".png"
        with open(out_path, "wb") as f:
            f.write(img_bytes)
    
print("yes")
# Out:
# train-00007-of-00029.parquet
# train-00005-of-00029.parquet
# train-00014-of-00029.parquet
# train-00027-of-00029.parquet
# train-00019-of-00029.parquet
# train-00026-of-00029.parquet
# train-00017-of-00029.parquet
# train-00018-of-00029.parquet
# train-00028-of-00029.parquet
# yes

# %%
directory_path = Path('training_images') # '.' refers to the current directory
files = [p for p in directory_path.iterdir() if p.is_file()]
train_files = list()
validation_files = list()

print(len(files))
# Out:
# 22370

# %%
directory_path = Path('hackdata/sentinel-beetles/data') # '.' refers to the current directory
files = [p for p in directory_path.iterdir() if p.is_file()]
train_files = list()
validation_files = list()

for file in files:
    if "train" in file.name:
        train_files.append(file.name)
    else:
        validation_files.append(file.name)
print(len(train_files))
print(len(validation_files))
out_dir = "validation_images"
os.makedirs(out_dir, exist_ok=True)
# Out:
# 29
# 4

# %%
for i in range(len(validation_files)):
    print(validation_files[i])
    df = pd.read_parquet(os.path.join(directory_path, validation_files[i]))

    for j in range(len(df)):
    # for j in range(1):
        img_bytes = df.loc[j, "file_path"]["bytes"]
        rel = str(df.loc[j, "relative_img_loc"])
        rel = rel.lstrip("/")
        out_path = os.path.join(out_dir, rel)
        if os.path.splitext(out_path)[1] == "":
            out_path += ".png"
        with open(out_path, "wb") as f:
            f.write(img_bytes)
print("yes")
# Out:
# validation-00002-of-00004.parquet
# validation-00003-of-00004.parquet
# validation-00000-of-00004.parquet
# validation-00001-of-00004.parquet
# yes

# %%
directory_path = Path('validation_images') # '.' refers to the current directory
files = [p for p in directory_path.iterdir() if p.is_file()]
train_files = list()
validation_files = list()

print(len(files))
# Out:
# 2486

# %%
#intaking 1 image and outputting 2 new images flipped over x and y axes to create extra fictional training data
#need to carry over all csv row info to new flipped images by appending it and creating a new csv
#og csv path: hackdata/sentinel-beetles/public_release/train.csv
#new csv path: UCSD_Smash_NSF_HDR_ML_2025_Challenge/prepro.csv

# %%
from PIL import Image

# Load your image
img = Image.open('/home/jovyan/UCSD_Smash_NSF_HDR_ML_2025_Challenge/UnityBeetleImages/4258269555.jpg')

# Mirror over Y-axis (horizontal flip)
mirror_y = img.transpose(Image.FLIP_LEFT_RIGHT)
mirror_y.save('4258269555_y.jpg')

# Mirror over X-axis (vertical flip)
mirror_x = img.transpose(Image.FLIP_TOP_BOTTOM)
mirror_x.save('4258269555_x.jpg')
